# %%
# Import required packages

import os
import earthpy as et
import pandas as pd
import macrosystems_module as macmo

# Create path to directory
directory_path = os.path.join(et.io.HOME, "earth-analytics", "data")

# Set working directory
os.chdir(directory_path)

# Download the data
et.data.get_data(url="https://raw.githubusercontent.com/rami8797/macrosystems_spectral_variance/main/data/NEON_Field_Site_Metadata_20220224.csv")

# Create path to metadata
metadata_path = os.path.join(
    "earthpy-downloads", "NEON_Field_Site_Metadata_20220224.csv")

# %%
# Use function to get site info
site_dictionary = macmo.get_site_dict(metadata_path, (-130, 25, -100, 50), 
                   "field_site_type", "Terrestrial", 
                   "field_dominant_nlcd_classes", "Evergreen Forest")
site_dictionary
# Out:
# {'ABBY': {'2017-06': ['NEON_D16_ABBY_DP3_557000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5060000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5074000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5074000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5074000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5060000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5075000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5074000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5060000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5060000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5060000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5074000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5060000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5074000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5074000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5060000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5060000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5060000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5075000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5060000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5074000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5074000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5074000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5074000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5074000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5060000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5060000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5074000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5060000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5060000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5074000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5059000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5074000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5074000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5060000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5060000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5074000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5074000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5060000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5060000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5060000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5060000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5060000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_560000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5060000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_545000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5060000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_560000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5060000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_545000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5060000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5073000_reflectance.h5'],
#   '2018-07': ['NEON_D16_ABBY_DP3_557000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_556000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5061000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_546000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_548000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_555000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5064000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5060000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_549000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_552000_5063000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_557000_5073000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5070000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_559000_5071000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5068000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_551000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_550000_5062000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5066000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_554000_5067000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5069000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_553000_5072000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_547000_5065000_reflectance.h5',
#    'NEON_D16_ABBY_DP3_558000_5071000_reflectance.h5',
# ...
#    'NEON_D12_YELL_DP3_533000_4971000_reflectance.h5',
#    'NEON_D12_YELL_DP3_539000_4981000_reflectance.h5',
#    'NEON_D12_YELL_DP3_531000_4970000_reflectance.h5',
#    'NEON_D12_YELL_DP3_535000_4976000_reflectance.h5',
#    'NEON_D12_YELL_DP3_533000_4972000_reflectance.h5',
#    'NEON_D12_YELL_DP3_540000_4980000_reflectance.h5',
#    'NEON_D12_YELL_DP3_534000_4975000_reflectance.h5',
#    'NEON_D12_YELL_DP3_535000_4974000_reflectance.h5',
#    'NEON_D12_YELL_DP3_539000_4979000_reflectance.h5',
#    'NEON_D12_YELL_DP3_528000_4974000_reflectance.h5',
#    'NEON_D12_YELL_DP3_538000_4978000_reflectance.h5',
#    'NEON_D12_YELL_DP3_544000_4979000_reflectance.h5',
#    'NEON_D12_YELL_DP3_550000_4975000_reflectance.h5',
#    'NEON_D12_YELL_DP3_530000_4975000_reflectance.h5',
#    'NEON_D12_YELL_DP3_548000_4974000_reflectance.h5',
#    'NEON_D12_YELL_DP3_544000_4972000_reflectance.h5',
#    'NEON_D12_YELL_DP3_535000_4975000_reflectance.h5',
#    'NEON_D12_YELL_DP3_547000_4975000_reflectance.h5',
#    'NEON_D12_YELL_DP3_539000_4982000_reflectance.h5',
#    'NEON_D12_YELL_DP3_529000_4980000_reflectance.h5',
#    'NEON_D12_YELL_DP3_541000_4982000_reflectance.h5',
#    'NEON_D12_YELL_DP3_534000_4968000_reflectance.h5',
#    'NEON_D12_YELL_DP3_527000_4977000_reflectance.h5',
#    'NEON_D12_YELL_DP3_542000_4978000_reflectance.h5',
#    'NEON_D12_YELL_DP3_537000_4977000_reflectance.h5',
#    'NEON_D12_YELL_DP3_546000_4977000_reflectance.h5',
#    'NEON_D12_YELL_DP3_546000_4974000_reflectance.h5',
#    'NEON_D12_YELL_DP3_548000_4977000_reflectance.h5',
#    'NEON_D12_YELL_DP3_541000_4980000_reflectance.h5',
#    'NEON_D12_YELL_DP3_532000_4982000_reflectance.h5',
#    'NEON_D12_YELL_DP3_545000_4977000_reflectance.h5',
#    'NEON_D12_YELL_DP3_547000_4972000_reflectance.h5',
#    'NEON_D12_YELL_DP3_530000_4968000_reflectance.h5',
#    'NEON_D12_YELL_DP3_537000_4976000_reflectance.h5',
#    'NEON_D12_YELL_DP3_534000_4974000_reflectance.h5',
#    'NEON_D12_YELL_DP3_532000_4969000_reflectance.h5',
#    'NEON_D12_YELL_DP3_548000_4970000_reflectance.h5',
#    'NEON_D12_YELL_DP3_546000_4976000_reflectance.h5',
#    'NEON_D12_YELL_DP3_525000_4976000_reflectance.h5',
#    'NEON_D12_YELL_DP3_529000_4982000_reflectance.h5',
#    'NEON_D12_YELL_DP3_542000_4983000_reflectance.h5',
#    'NEON_D12_YELL_DP3_525000_4975000_reflectance.h5',
#    'NEON_D12_YELL_DP3_532000_4975000_reflectance.h5',
#    'NEON_D12_YELL_DP3_547000_4973000_reflectance.h5',
#    'NEON_D12_YELL_DP3_531000_4978000_reflectance.h5',
#    'NEON_D12_YELL_DP3_533000_4973000_reflectance.h5',
#    'NEON_D12_YELL_DP3_543000_4982000_reflectance.h5',
#    'NEON_D12_YELL_DP3_537000_4974000_reflectance.h5',
#    'NEON_D12_YELL_DP3_549000_4975000_reflectance.h5',
#    'NEON_D12_YELL_DP3_530000_4970000_reflectance.h5',
#    'NEON_D12_YELL_DP3_542000_4979000_reflectance.h5',
#    'NEON_D12_YELL_DP3_535000_4967000_reflectance.h5',
#    'NEON_D12_YELL_DP3_530000_4974000_reflectance.h5',
#    'NEON_D12_YELL_DP3_543000_4972000_reflectance.h5',
#    'NEON_D12_YELL_DP3_531000_4979000_reflectance.h5',
#    'NEON_D12_YELL_DP3_537000_4968000_reflectance.h5',
#    'NEON_D12_YELL_DP3_529000_4979000_reflectance.h5',
#    'NEON_D12_YELL_DP3_538000_4972000_reflectance.h5',
#    'NEON_D12_YELL_DP3_537000_4970000_reflectance.h5',
#    'NEON_D12_YELL_DP3_533000_4976000_reflectance.h5',
#    'NEON_D12_YELL_DP3_549000_4972000_reflectance.h5',
#    'NEON_D12_YELL_DP3_532000_4978000_reflectance.h5',
#    'NEON_D12_YELL_DP3_537000_4981000_reflectance.h5',
#    'NEON_D12_YELL_DP3_527000_4974000_reflectance.h5',
#    'NEON_D12_YELL_DP3_530000_4980000_reflectance.h5',
#    'NEON_D12_YELL_DP3_534000_4981000_reflectance.h5',
#    'NEON_D12_YELL_DP3_526000_4978000_reflectance.h5',
#    'NEON_D12_YELL_DP3_546000_4971000_reflectance.h5',
#    'NEON_D12_YELL_DP3_540000_4970000_reflectance.h5',
#    'NEON_D12_YELL_DP3_535000_4979000_reflectance.h5',
#    'NEON_D12_YELL_DP3_531000_4973000_reflectance.h5',
#    'NEON_D12_YELL_DP3_544000_4977000_reflectance.h5',
#    'NEON_D12_YELL_DP3_537000_4980000_reflectance.h5',
#    'NEON_D12_YELL_DP3_542000_4980000_reflectance.h5',
#    'NEON_D12_YELL_DP3_547000_4970000_reflectance.h5',
#    'NEON_D12_YELL_DP3_543000_4974000_reflectance.h5',
#    'NEON_D12_YELL_DP3_539000_4969000_reflectance.h5',
#    'NEON_D12_YELL_DP3_546000_4975000_reflectance.h5',
#    'NEON_D12_YELL_DP3_534000_4977000_reflectance.h5',
#    'NEON_D12_YELL_DP3_536000_4971000_reflectance.h5',
#    'NEON_D12_YELL_DP3_539000_4972000_reflectance.h5',
#    'NEON_D12_YELL_DP3_526000_4974000_reflectance.h5',
#    'NEON_D12_YELL_DP3_530000_4982000_reflectance.h5',
#    'NEON_D12_YELL_DP3_534000_4966000_reflectance.h5',
#    'NEON_D12_YELL_DP3_530000_4976000_reflectance.h5',
#    'NEON_D12_YELL_DP3_542000_4976000_reflectance.h5',
#    'NEON_D12_YELL_DP3_530000_4971000_reflectance.h5',
#    'NEON_D12_YELL_DP3_541000_4979000_reflectance.h5',
#    'NEON_D12_YELL_DP3_538000_4968000_reflectance.h5',
#    'NEON_D12_YELL_DP3_528000_4977000_reflectance.h5',
#    'NEON_D12_YELL_DP3_534000_4972000_reflectance.h5',
#    'NEON_D12_YELL_DP3_535000_4977000_reflectance.h5',
#    'NEON_D12_YELL_DP3_546000_4973000_reflectance.h5',
#    'NEON_D12_YELL_DP3_539000_4971000_reflectance.h5',
#    'NEON_D12_YELL_DP3_527000_4979000_reflectance.h5',
#    'NEON_D12_YELL_DP3_535000_4972000_reflectance.h5',
#    'NEON_D12_YELL_DP3_532000_4972000_reflectance.h5',
#    'NEON_D12_YELL_DP3_527000_4975000_reflectance.h5',
#    'NEON_D12_YELL_DP3_536000_4978000_reflectance.h5',
#    'NEON_D12_YELL_DP3_540000_4974000_reflectance.h5',
#    'NEON_D12_YELL_DP3_535000_4973000_reflectance.h5',
#    'NEON_D12_YELL_DP3_535000_4971000_reflectance.h5',
#    'NEON_D12_YELL_DP3_534000_4976000_reflectance.h5',
#    'NEON_D12_YELL_DP3_540000_4979000_reflectance.h5',
#    'NEON_D12_YELL_DP3_528000_4973000_reflectance.h5',
#    'NEON_D12_YELL_DP3_543000_4977000_reflectance.h5',
#    'NEON_D12_YELL_DP3_543000_4973000_reflectance.h5',
#    'NEON_D12_YELL_DP3_545000_4979000_reflectance.h5',
#    'NEON_D12_YELL_DP3_550000_4976000_reflectance.h5',
#    'NEON_D12_YELL_DP3_535000_4980000_reflectance.h5',
#    'NEON_D12_YELL_DP3_538000_4976000_reflectance.h5',
#    'NEON_D12_YELL_DP3_538000_4981000_reflectance.h5',
#    'NEON_D12_YELL_DP3_547000_4981000_reflectance.h5',
#    'NEON_D12_YELL_DP3_532000_4974000_reflectance.h5',
#    'NEON_D12_YELL_DP3_535000_4981000_reflectance.h5',
#    'NEON_D12_YELL_DP3_535000_4970000_reflectance.h5',
#    'NEON_D12_YELL_DP3_545000_4970000_reflectance.h5',
#    'NEON_D12_YELL_DP3_536000_4981000_reflectance.h5',
#    'NEON_D12_YELL_DP3_532000_4981000_reflectance.h5',
#    'NEON_D12_YELL_DP3_532000_4976000_reflectance.h5',
#    'NEON_D12_YELL_DP3_538000_4969000_reflectance.h5',
#    'NEON_D12_YELL_DP3_533000_4968000_reflectance.h5',
#    'NEON_D12_YELL_DP3_542000_4982000_reflectance.h5',
#    'NEON_D12_YELL_DP3_544000_4973000_reflectance.h5',
#    'NEON_D12_YELL_DP3_533000_4982000_reflectance.h5',
#    'NEON_D12_YELL_DP3_546000_4982000_reflectance.h5',
#    'NEON_D12_YELL_DP3_549000_4971000_reflectance.h5',
#    'NEON_D12_YELL_DP3_534000_4970000_reflectance.h5',
#    'NEON_D12_YELL_DP3_546000_4978000_reflectance.h5',
#    'NEON_D12_YELL_DP3_528000_4976000_reflectance.h5',
#    'NEON_D12_YELL_DP3_531000_4981000_reflectance.h5',
#    'NEON_D12_YELL_DP3_545000_4973000_reflectance.h5',
#    'NEON_D12_YELL_DP3_537000_4969000_reflectance.h5',
#    'NEON_D12_YELL_DP3_533000_4980000_reflectance.h5',
#    'NEON_D12_YELL_DP3_535000_4968000_reflectance.h5',
#    'NEON_D12_YELL_DP3_538000_4975000_reflectance.h5',
#    'NEON_D12_YELL_DP3_549000_4976000_reflectance.h5',
#    'NEON_D12_YELL_DP3_544000_4982000_reflectance.h5',
#    'NEON_D12_YELL_DP3_529000_4973000_reflectance.h5',
#    'NEON_D12_YELL_DP3_526000_4973000_reflectance.h5',
#    'NEON_D12_YELL_DP3_531000_4968000_reflectance.h5',
#    'NEON_D12_YELL_DP3_547000_4977000_reflectance.h5',
#    'NEON_D12_YELL_DP3_536000_4968000_reflectance.h5',
#    'NEON_D12_YELL_DP3_534000_4979000_reflectance.h5',
#    'NEON_D12_YELL_DP3_539000_4977000_reflectance.h5',
#    'NEON_D12_YELL_DP3_536000_4979000_reflectance.h5',
#    'NEON_D12_YELL_DP3_534000_4969000_reflectance.h5',
#    'NEON_D12_YELL_DP3_528000_4975000_reflectance.h5',
#    'NEON_D12_YELL_DP3_547000_4979000_reflectance.h5',
#    'NEON_D12_YELL_DP3_548000_4978000_reflectance.h5',
#    'NEON_D12_YELL_DP3_531000_4971000_reflectance.h5',
#    'NEON_D12_YELL_DP3_532000_4968000_reflectance.h5',
#    'NEON_D12_YELL_DP3_545000_4972000_reflectance.h5',
#    'NEON_D12_YELL_DP3_533000_4970000_reflectance.h5',
#    'NEON_D12_YELL_DP3_530000_4969000_reflectance.h5',
#    'NEON_D12_YELL_DP3_534000_4982000_reflectance.h5',
#    'NEON_D12_YELL_DP3_536000_4973000_reflectance.h5',
#    'NEON_D12_YELL_DP3_531000_4974000_reflectance.h5',
#    'NEON_D12_YELL_DP3_543000_4979000_reflectance.h5',
#    'NEON_D12_YELL_DP3_536000_4967000_reflectance.h5',
#    'NEON_D12_YELL_DP3_530000_4977000_reflectance.h5',
#    'NEON_D12_YELL_DP3_540000_4971000_reflectance.h5',
#    'NEON_D12_YELL_DP3_535000_4969000_reflectance.h5',
#    'NEON_D12_YELL_DP3_547000_4980000_reflectance.h5',
#    'NEON_D12_YELL_DP3_539000_4974000_reflectance.h5',
#    'NEON_D12_YELL_DP3_527000_4978000_reflectance.h5',
#    'NEON_D12_YELL_DP3_541000_4976000_reflectance.h5',
#    'NEON_D12_YELL_DP3_534000_4973000_reflectance.h5',
#    'NEON_D12_YELL_DP3_547000_4978000_reflectance.h5',
#    'NEON_D12_YELL_DP3_543000_4976000_reflectance.h5',
#    'NEON_D12_YELL_DP3_534000_4971000_reflectance.h5',
#    'NEON_D12_YELL_DP3_540000_4976000_reflectance.h5',
#    'NEON_D12_YELL_DP3_544000_4975000_reflectance.h5',
#    'NEON_D12_YELL_DP3_545000_4983000_reflectance.h5',
#    'NEON_D12_YELL_DP3_540000_4973000_reflectance.h5',
#    'NEON_D12_YELL_DP3_536000_4969000_reflectance.h5',
#    'NEON_D12_YELL_DP3_543000_4978000_reflectance.h5',
#    'NEON_D12_YELL_DP3_537000_4975000_reflectance.h5',
#    'NEON_D12_YELL_DP3_529000_4975000_reflectance.h5',
#    'NEON_D12_YELL_DP3_545000_4976000_reflectance.h5',
#    'NEON_D12_YELL_DP3_541000_4977000_reflectance.h5',
#    'NEON_D12_YELL_DP3_530000_4973000_reflectance.h5',
#    'NEON_D12_YELL_DP3_547000_4976000_reflectance.h5',
#    'NEON_D12_YELL_DP3_533000_4979000_reflectance.h5',
#    'NEON_D12_YELL_DP3_546000_4983000_reflectance.h5',
#    'NEON_D12_YELL_DP3_533000_4977000_reflectance.h5',
#    'NEON_D12_YELL_DP3_544000_4974000_reflectance.h5',
#    'NEON_D12_YELL_DP3_533000_4966000_reflectance.h5',
#    'NEON_D12_YELL_DP3_539000_4973000_reflectance.h5',
#    'NEON_D12_YELL_DP3_543000_4975000_reflectance.h5',
#    'NEON_D12_YELL_DP3_539000_4975000_reflectance.h5',
#    'NEON_D12_YELL_DP3_549000_4970000_reflectance.h5',
#    'NEON_D12_YELL_DP3_546000_4979000_reflectance.h5',
#    'NEON_D12_YELL_DP3_530000_4979000_reflectance.h5',
#    'NEON_D12_YELL_DP3_534000_4967000_reflectance.h5',
#    'NEON_D12_YELL_DP3_531000_4975000_reflectance.h5',
#    'NEON_D12_YELL_DP3_532000_4979000_reflectance.h5',
#    'NEON_D12_YELL_DP3_540000_4977000_reflectance.h5',
#    'NEON_D12_YELL_DP3_532000_4967000_reflectance.h5',
#    'NEON_D12_YELL_DP3_532000_4971000_reflectance.h5',
#    'NEON_D12_YELL_DP3_548000_4972000_reflectance.h5',
#    'NEON_D12_YELL_DP3_543000_4980000_reflectance.h5',
#    'NEON_D12_YELL_DP3_540000_4978000_reflectance.h5',
#    'NEON_D12_YELL_DP3_538000_4973000_reflectance.h5',
#    'NEON_D12_YELL_DP3_540000_4972000_reflectance.h5',
#    'NEON_D12_YELL_DP3_539000_4980000_reflectance.h5',
#    'NEON_D12_YELL_DP3_541000_4981000_reflectance.h5',
#    'NEON_D12_YELL_DP3_533000_4967000_reflectance.h5',
#    'NEON_D12_YELL_DP3_545000_4975000_reflectance.h5',
#    'NEON_D12_YELL_DP3_526000_4975000_reflectance.h5',
#    'NEON_D12_YELL_DP3_531000_4980000_reflectance.h5',
#    'NEON_D12_YELL_DP3_533000_4974000_reflectance.h5',
#    'NEON_D12_YELL_DP3_547000_4971000_reflectance.h5',
#    'NEON_D12_YELL_DP3_536000_4975000_reflectance.h5',
#    'NEON_D12_YELL_DP3_535000_4966000_reflectance.h5',
#    'NEON_D12_YELL_DP3_530000_4978000_reflectance.h5',
#    'NEON_D12_YELL_DP3_544000_4983000_reflectance.h5',
#    'NEON_D12_YELL_DP3_524000_4976000_reflectance.h5',
#    'NEON_D12_YELL_DP3_529000_4974000_reflectance.h5',
#    'NEON_D12_YELL_DP3_531000_4969000_reflectance.h5',
#    'NEON_D12_YELL_DP3_541000_4973000_reflectance.h5',
#    'NEON_D12_YELL_DP3_536000_4976000_reflectance.h5',
#    'NEON_D12_YELL_DP3_541000_4978000_reflectance.h5',
#    'NEON_D12_YELL_DP3_549000_4974000_reflectance.h5',
#    'NEON_D12_YELL_DP3_542000_4974000_reflectance.h5',
#    'NEON_D12_YELL_DP3_539000_4978000_reflectance.h5',
#    'NEON_D12_YELL_DP3_545000_4984000_reflectance.h5',
#    'NEON_D12_YELL_DP3_529000_4976000_reflectance.h5',
#    'NEON_D12_YELL_DP3_543000_4971000_reflectance.h5',
#    'NEON_D12_YELL_DP3_526000_4977000_reflectance.h5',
#    'NEON_D12_YELL_DP3_532000_4977000_reflectance.h5',
#    'NEON_D12_YELL_DP3_532000_4970000_reflectance.h5',
#    'NEON_D12_YELL_DP3_529000_4977000_reflectance.h5',
#    'NEON_D12_YELL_DP3_533000_4969000_reflectance.h5',
#    'NEON_D12_YELL_DP3_527000_4976000_reflectance.h5',
#    'NEON_D12_YELL_DP3_544000_4970000_reflectance.h5',
#    'NEON_D12_YELL_DP3_529000_4978000_reflectance.h5',
#    'NEON_D12_YELL_DP3_536000_4977000_reflectance.h5',
#    'NEON_D12_YELL_DP3_541000_4975000_reflectance.h5',
#    'NEON_D12_YELL_DP3_531000_4972000_reflectance.h5',
#    'NEON_D12_YELL_DP3_529000_4981000_reflectance.h5',
#    'NEON_D12_YELL_DP3_536000_4970000_reflectance.h5',
#    'NEON_D12_YELL_DP3_531000_4976000_reflectance.h5',
#    'NEON_D12_YELL_DP3_549000_4977000_reflectance.h5',
#    'NEON_D12_YELL_DP3_540000_4981000_reflectance.h5',
#    'NEON_D12_YELL_DP3_548000_4975000_reflectance.h5',
#    'NEON_D12_YELL_DP3_538000_4979000_reflectance.h5',
#    'NEON_D12_YELL_DP3_538000_4971000_reflectance.h5',
#    'NEON_D12_YELL_DP3_530000_4972000_reflectance.h5',
#    'NEON_D12_YELL_DP3_548000_4971000_reflectance.h5',
#    'NEON_D12_YELL_DP3_544000_4971000_reflectance.h5',
#    'NEON_D12_YELL_DP3_546000_4970000_reflectance.h5',
#    'NEON_D12_YELL_DP3_532000_4980000_reflectance.h5',
#    'NEON_D12_YELL_DP3_537000_4979000_reflectance.h5',
#    'NEON_D12_YELL_DP3_528000_4980000_reflectance.h5',
#    'NEON_D12_YELL_DP3_547000_4974000_reflectance.h5',
#    'NEON_D12_YELL_DP3_544000_4976000_reflectance.h5',
#    'NEON_D12_YELL_DP3_542000_4975000_reflectance.h5',
#    'NEON_D12_YELL_DP3_538000_4977000_reflectance.h5',
#    'NEON_D12_YELL_DP3_537000_4978000_reflectance.h5',
#    'NEON_D12_YELL_DP3_530000_4981000_reflectance.h5',
#    'NEON_D12_YELL_DP3_541000_4974000_reflectance.h5',
#    'NEON_D12_YELL_DP3_538000_4974000_reflectance.h5',
#    'NEON_D12_YELL_DP3_543000_4983000_reflectance.h5',
#    'NEON_D12_YELL_DP3_540000_4982000_reflectance.h5',
#    'NEON_D12_YELL_DP3_537000_4971000_reflectance.h5',
#    'NEON_D12_YELL_DP3_546000_4972000_reflectance.h5',
#    'NEON_D12_YELL_DP3_528000_4978000_reflectance.h5',
#    'NEON_D12_YELL_DP3_548000_4976000_reflectance.h5',
#    'NEON_D12_YELL_DP3_548000_4973000_reflectance.h5',
#    'NEON_D12_YELL_DP3_532000_4966000_reflectance.h5',
#    'NEON_D12_YELL_DP3_537000_4973000_reflectance.h5',
#    'NEON_D12_YELL_DP3_539000_4970000_reflectance.h5',
#    'NEON_D12_YELL_DP3_547000_4982000_reflectance.h5',
#    'NEON_D12_YELL_DP3_533000_4981000_reflectance.h5',
#    'NEON_D12_YELL_DP3_545000_4974000_reflectance.h5',
#    'NEON_D12_YELL_DP3_544000_4978000_reflectance.h5',
#    'NEON_D12_YELL_DP3_537000_4972000_reflectance.h5',
#    'NEON_D12_YELL_DP3_531000_4967000_reflectance.h5',
#    'NEON_D12_YELL_DP3_536000_4974000_reflectance.h5',
#    'NEON_D12_YELL_DP3_535000_4978000_reflectance.h5',
#    'NEON_D12_YELL_DP3_539000_4976000_reflectance.h5',
#    'NEON_D12_YELL_DP3_528000_4979000_reflectance.h5',
#    'NEON_D12_YELL_DP3_536000_4972000_reflectance.h5',
#    'NEON_D12_YELL_DP3_549000_4978000_reflectance.h5',
#    'NEON_D12_YELL_DP3_538000_4980000_reflectance.h5',
#    'NEON_D12_YELL_DP3_535000_4982000_reflectance.h5',
#    'NEON_D12_YELL_DP3_534000_4980000_reflectance.h5',
#    'NEON_D12_YELL_DP3_536000_4980000_reflectance.h5',
#    'NEON_D12_YELL_DP3_531000_4977000_reflectance.h5',
#    'NEON_D12_YELL_DP3_549000_4973000_reflectance.h5',
#    'NEON_D12_YELL_DP3_545000_4982000_reflectance.h5',
#    'NEON_D12_YELL_DP3_540000_4975000_reflectance.h5',
#    'NEON_D12_YELL_DP3_542000_4977000_reflectance.h5',
#    'NEON_D12_YELL_DP3_542000_4973000_reflectance.h5',
#    'NEON_D12_YELL_DP3_534000_4978000_reflectance.h5']}}

# %%
# Download one of the data files reported by the dictionary
et.data.get_data(url="https://storage.googleapis.com/neon-aop-products/2018/FullSite/D13/2018_NIWO_2/L3/Spectrometer/Reflectance/NEON_D13_NIWO_DP3_445000_4433000_reflectance.h5")
# Out:
# 'C:\\Users\\Rachel\\earth-analytics\\data\\earthpy-downloads\\NEON_D13_NIWO_DP3_445000_4433000_reflectance.h5'

# %%
# Create path to h5 file
h5_path = os.path.join("earthpy-downloads", "NEON_D13_NIWO_DP3_445000_4433000_reflectance.h5")

# %%
# Get clean array dataframe
clean_h5 = macmo.clean_h5_refl_df(h5_path)

# Show output
clean_h5
# Out:
#       wavelength                                        reflectance  site
# 0     381.375793  [[0.0384, 0.0422, 0.0406, 0.0339, 0.0371, 0.02...  NIWO
# 1     386.385986  [[0.0503, 0.0563, 0.0555, 0.0454, 0.0417, 0.03...  NIWO
# 2     391.396301  [[0.0534, 0.0583, 0.0577, 0.0454, 0.0454, 0.03...  NIWO
# 3     396.406586  [[0.0601, 0.0655, 0.0631, 0.0498, 0.0479, 0.03...  NIWO
# 4     401.416901  [[0.0527, 0.0581, 0.0583, 0.0462, 0.0467, 0.03...  NIWO
# ..           ...                                                ...   ...
# 421  2490.703125  [[0.123, 0.1477, 0.1493, 0.0912, 0.0803, 0.026...  NIWO
# 422  2495.713379  [[0.1306, 0.1664, 0.1569, 0.0776, 0.0812, 0.03...  NIWO
# 423  2500.723633  [[0.1121, 0.1527, 0.1438, 0.0745, 0.072, 0.022...  NIWO
# 424  2505.733887  [[0.1269, 0.1538, 0.1488, 0.0818, 0.0751, 0.02...  NIWO
# 425  2510.744141  [[0.135, 0.181, 0.1729, 0.0862, 0.0731, 0.0302...  NIWO
#
# [426 rows x 3 columns]

# %%
# Make list of wavelengths to be extracted from clean_h5 dataframe
wavelength_list = [(444, 472), 
                   (475, 507), 
                   (531, 545), 
                   (560, 587), 
                   (650, 666), 
                   (668, 682), 
                   (705, 715), 
                   (717, 729), 
                   (740, 758), 
                   (842, 899)]

# %%
# Loop throughlist of wavelengths to extract them from clean_h5 dataframe
wavelength_df_list = []
for range in wavelength_list:
    wavelength_df = macmo.select_wavelength(clean_h5, range)
    wavelength_df_list.append(wavelength_df)

# Put extracted wavelength dataframes into a single dataframe
wavelength_df = pd.concat(wavelength_df_list)

# Look at output that will allow you to plot reflectance distributions
wavelength_df
# Out:
#      wavelength reflectance  site
# 13   446.509399      0.0595  NIWO
# 13   446.509399      0.0657  NIWO
# 13   446.509399      0.0662  NIWO
# 13   446.509399      0.0512  NIWO
# 13   446.509399      0.0462  NIWO
# ..          ...         ...   ...
# 103  897.434509      0.1689  NIWO
# 103  897.434509      0.1708  NIWO
# 103  897.434509      0.1744  NIWO
# 103  897.434509      0.1783  NIWO
# 103  897.434509      0.1724  NIWO
#
# [49000000 rows x 3 columns]
